# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Heart rate

# %%
hr = pd.read_csv('../data/fitbit_apr/heartrate_seconds_merged.csv')
hr
# Out:
#                  Id                  Time  Value
# 0        2022484408  4/12/2016 7:21:00 AM     97
# 1        2022484408  4/12/2016 7:21:05 AM    102
# 2        2022484408  4/12/2016 7:21:10 AM    105
# 3        2022484408  4/12/2016 7:21:20 AM    103
# 4        2022484408  4/12/2016 7:21:25 AM    101
# ...             ...                   ...    ...
# 2483653  8877689391  5/12/2016 2:43:53 PM     57
# 2483654  8877689391  5/12/2016 2:43:58 PM     56
# 2483655  8877689391  5/12/2016 2:44:03 PM     55
# 2483656  8877689391  5/12/2016 2:44:18 PM     55
# 2483657  8877689391  5/12/2016 2:44:28 PM     56
#
# [2483658 rows x 3 columns]

# %%
hr.Time = pd.to_datetime(hr.Time)

# %%
g = sns.FacetGrid(data=hr, col='Id', col_wrap=3)
g.map_dataframe(sns.scatterplot, x='Time', y='Value', size=10)

# %% [markdown]
# # Sleep

# %%
sleep = pd.read_csv('../data/fitbit_apr/sleepDay_merged.csv')
sleep
# Out:
#              Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0    1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1    1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2    1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3    1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4    1503960366  4/17/2016 12:00:00 AM                  1                 700
# ..          ...                    ...                ...                 ...
# 408  8792009665  4/30/2016 12:00:00 AM                  1                 343
# 409  8792009665   5/1/2016 12:00:00 AM                  1                 503
# 410  8792009665   5/2/2016 12:00:00 AM                  1                 415
# 411  8792009665   5/3/2016 12:00:00 AM                  1                 516
# 412  8792009665   5/4/2016 12:00:00 AM                  1                 439
#
#      TotalTimeInBed
# ...

# %%
sleep.SleepDay = pd.to_datetime(sleep.SleepDay)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_27888\3327113786.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sleep.SleepDay = pd.to_datetime(sleep.SleepDay)

# %%
g = sns.FacetGrid(data=sleep, col='Id', col_wrap=3)
g.map_dataframe(sns.scatterplot, x='SleepDay', y='TotalMinutesAsleep')

# %% [markdown]
# # Steps

# %%
steps = pd.read_csv('../data/fitbit_apr/hourlySteps_merged.csv')
steps
# Out:
#                Id           ActivityHour  StepTotal
# 0      1503960366  4/12/2016 12:00:00 AM        373
# 1      1503960366   4/12/2016 1:00:00 AM        160
# 2      1503960366   4/12/2016 2:00:00 AM        151
# 3      1503960366   4/12/2016 3:00:00 AM          0
# 4      1503960366   4/12/2016 4:00:00 AM          0
# ...           ...                    ...        ...
# 22094  8877689391  5/12/2016 10:00:00 AM        514
# 22095  8877689391  5/12/2016 11:00:00 AM       1407
# 22096  8877689391  5/12/2016 12:00:00 PM       3135
# 22097  8877689391   5/12/2016 1:00:00 PM        307
# 22098  8877689391   5/12/2016 2:00:00 PM        457
#
# [22099 rows x 3 columns]

# %%
steps.ActivityHour = pd.to_datetime(steps.ActivityHour)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_27888\1754661219.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   steps.ActivityHour = pd.to_datetime(steps.ActivityHour)

# %%
g = sns.FacetGrid(data=steps, col='Id', col_wrap=3)
g.map_dataframe(sns.scatterplot, x='ActivityHour', y='StepTotal', size=10)
